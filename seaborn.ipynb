# %%
import seaborn as sns
tips= sns.load_dataset('tips')
sns.displot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_7672\4271412032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <AxesSubplot: xlabel='total_bill', ylabel='Density'>

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='sex')

# %%
sns.barplot(x='sex', y='total_bill', data=tips)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.heatmap(tips.corr())
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_7672\1579789445.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tips.corr())
# <AxesSubplot: >

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# flight_pivoted_df= df.pivot_table(index='column_name', columns='column_name', values='column_name')
# in .pivot_table() we have index, columns and values.

# %%
#grids:
g= sns.PairGrid(tips)
import matplotlib.pyplot as plt
g.map(plt.scatter)

# %%
# g.map_diag(plt.scatter)
# g.map_lower(plt.hist)
g.map_upper(sns.kdeplot)

# %%
#facetGrid
# fg= sns.FacetGrid(data=tips,row='total_bill', col='sex')
# fg.map(sns.distplot, 'tip')
